# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

# %%
# fg 2N

fg_2N = np.array([[0.0000000e+00, 1.1131539e+00, 2.3339730e-05, 7.6116383e-01, 7.5329965e-01,
  7.1627230e-01, 1.3481606e+00, 1.2524132e+00, 8.2606330e-01, 8.5921250e-01],
 [0.0000000e+00, 1.0119130e-05, 1.0746952e-05, 5.6980366e-01, 3.9786568e-01,
  2.1371973e-01, 1.0613452e-06, 9.4128680e-02, 8.2606330e-01, 5.8187705e-01],
 [0.0000000e+00, 7.3131996e-01, 1.9328287e-05, 6.9864677e-06, 3.0922465e-06,
  3.9627960e-05, 8.1247690e-05, 3.5310359e-06, 2.9079030e-01, 6.5888260e-01],
 [0.0000000e+00, 2.3360129e-01, 1.0087875e-05, 2.6647210e-01, 2.3379730e-05,
  1.6095254e-01, 1.1923095e-05, 2.6652747e-09, 3.8021850e-01, 6.6661245e-01]])

fg_4N = np.array([[0.0000000e+00, 4.8942767e-02, 4.5898990e-01, 2.7072486e-01, 3.3405960e-05,
  4.7238440e-05, 3.1229443e-05, 1.5959307e-09, 1.2076304e-03, 2.3262458e-01],
 [0.0000000e+00, 5.8532105e-06, 1.3935164e-01, 1.5408150e-06, 1.6821685e-05,
  2.4882750e-05, 9.9825880e-05, 6.8328160e-10, 3.3243180e-01, 6.4359040e-02],
 [0.0000000e+00, 1.2257206e-06, 2.0507825e-06, 5.5031530e-06, 1.4426978e-05,
  1.0655858e-06, 1.1365548e-05, 8.8011960e-10, 5.7977897e-01, 2.4624155e-01],
 [0.0000000e+00, 2.1821547e-01, 8.5874290e-03, 2.6773840e-05, 2.6213222e-05,
  1.8087365e-05, 6.9107773e-07, 3.9276630e-09, 9.3644920e-01, 4.8527053e-01]])

# %%
# Calculate the mean and standard deviation for each column
fig, ((ax0)) = plt.subplots(nrows=1, ncols=1, sharey=True, figsize=(6, 6))

means1 = np.mean(fg_2N, axis=0)
std_devs1 = np.std(fg_2N, axis=0)

# means11 = np.mean(fg_2N_ic, axis=0)
# std_devs11 = np.std(fg_2N_ic, axis=0)

means2 = np.mean(fg_4N, axis=0)
std_devs2 = np.std(fg_4N, axis=0)

my_xlabels = ['0 nM', '3.125 nM', '6.25 nM', '12.5 nM', '25 nM', '50 nM', '100 nM', '200 nM', '400 nM', '800 nM']
    
# Generate a plot with error bars
x = np.arange(1, 11)  # X-axis points for each column

ax0.set_title(r"$f_g$",fontsize = 20)
ax0.errorbar(x, means1, yerr=std_devs1, fmt='o', capsize=5, color='b', ecolor='b', label='2N')
ax0.errorbar(x, means2, yerr=std_devs2, fmt='o', capsize=5, color='r', ecolor='r', label='4N')
ax0.set_xticks(x, my_xlabels, rotation ='vertical')
ax0.set_xlabel("Drug dose",fontsize = 20)
ax0.legend()


# ax1.set_title(r"$f_g$",fontsize = 20)
# ax1.plot(x,  fg_2N_ic, 'ko', label='2N, using IC50')
# ax1.plot(x,  fg_4N_ic, 'mo', label='4N, using IC50')
# ax1.legend()
# ax1.set_xticks(x, my_xlabels, rotation ='vertical')
# ax1.set_xlabel("Drug dose",fontsize = 20)




plt.show()

# %%
# fm 2N

fm_2N = np.array([[0.0000000e+00, 9.4377910e-01, 8.0744940e-01, 1.0112497e+00, 1.0807875e+00,
  1.1961753e+00, 1.9399306e+00, 2.8676740e+00, 1.6763363e+00, 7.8618310e-01],
 [0.0000000e+00, 4.3780208e-01, 8.1360054e-01, 1.0123497e+00, 1.0451822e+00,
  1.0797468e+00, 1.0878615e+00, 7.4649600e-01, 1.6763363e+00, 2.0523748e-01],
 [0.0000000e+00, 7.6392233e-01, 8.7208277e-01, 9.7404370e-01, 1.0270900e+00,
  1.0719625e+00, 1.0347699e+00, 6.7372054e-01, 1.1594417e-01, 2.0607180e-09],
 [0.0000000e+00, 3.7445915e-01, 7.0156340e-01, 9.9784740e-01, 1.0168365e+00,
  1.0826944e+00, 1.0292679e+00, 2.6758054e-01, 3.5040160e-01, 8.8314515e-01]])

fm_4N = np.array([[0.0000000e+00, 3.3381486e-05, 6.6858166e-01, 8.6827725e-01, 1.0007280e+00,
  1.0342630e+00, 1.1036727e+00, 1.1927582e+00, 1.1070297e+00, 6.6367507e-01],
 [0.0000000e+00, 2.8474462e-01, 6.7333984e-01, 9.0340980e-01, 9.9840050e-01,
  1.0428274e+00, 1.1073649e+00, 1.2320665e+00, 1.5453370e+00, 6.2953514e-01],
 [0.0000000e+00, 6.8456426e-02, 2.3787631e-01, 8.2989380e-01, 9.9280643e-01,
  1.0486866e+00, 1.1008618e+00, 1.2268244e+00, 1.5721480e+00, 4.8834476e-01],
 [0.0000000e+00, 1.4673647e-01, 2.0006588e-01, 8.9286816e-01, 1.0128875e+00,
  1.0503994e+00, 1.1142932e+00, 1.1838260e+00, 1.8301921e+00, 1.3985010e+00]])

# %%
# Calculate the mean and standard deviation for each column
fig, ((ax0)) = plt.subplots(nrows=1, ncols=1, sharey=True, figsize=(6, 6))

means1 = np.mean(fm_2N, axis=0)
std_devs1 = np.std(fm_2N, axis=0)

# means11 = np.mean(fg_2N_ic, axis=0)
# std_devs11 = np.std(fg_2N_ic, axis=0)

means2 = np.mean(fm_4N, axis=0)
std_devs2 = np.std(fm_4N, axis=0)

my_xlabels = ['0 nM', '3.125 nM', '6.25 nM', '12.5 nM', '25 nM', '50 nM', '100 nM', '200 nM', '400 nM', '800 nM']
    
# Generate a plot with error bars
x = np.arange(1, 11)  # X-axis points for each column

ax0.set_title(r"$f_m$",fontsize = 20)
ax0.errorbar(x, means1, yerr=std_devs1, fmt='o', capsize=5, color='b', ecolor='b', label='2N')
ax0.errorbar(x, means2, yerr=std_devs2, fmt='o', capsize=5, color='r', ecolor='r', label='4N')
ax0.set_xticks(x, my_xlabels, rotation ='vertical')
ax0.set_xlabel("Drug dose",fontsize = 20)
ax0.legend()


# ax1.set_title(r"$f_g$",fontsize = 20)
# ax1.plot(x,  fg_2N_ic, 'ko', label='2N, using IC50')
# ax1.plot(x,  fg_4N_ic, 'mo', label='4N, using IC50')
# ax1.legend()
# ax1.set_xticks(x, my_xlabels, rotation ='vertical')
# ax1.set_xlabel("Drug dose",fontsize = 20)




plt.show()

# %%
# fm 2N

fp_2N = np.array([[0.,         2.3675585,  2.0306816,  2.3978627,  3.4738712,  4.6139936,
  4.6091604,  4.6720433,  2.5299864,  0.49950662],
 [0.       , 1.2736831,  2.0993881,  2.257992,   3.488794,   4.1813307,
  5.964126,   1.1117533,  2.5299864,  2.3709762 ],
 [0.      ,   2.359938,   2.0659506,  2.3772602,  3.314922,   5.2413144,
  6.0317597,  4.7066464,  0.55953336, 1.823251,  ],
 [0.       ,  1.7241403,  2.0993211,  2.1774185,  3.4345367,  4.805375,
  4.4821653,  3.6936858,  0.85492235, 0.29803842]])

fp_4N = np.array([[0.,         0.93288296, 2.8191557,  3.2862406,  4.280553,   5.092544,
  4.218063,   3.2976458,  1.9487678,  1.1221453 ],
 [0.,         1.0649403,  2.0293932,  2.5255768,  4.1156373,  6.0146546,
  6.2910576,  3.1543045,  2.7516282,  1.0969592 ],
 [0.,         0.9525176,  0.6392054,  2.6088068,  4.2057157,  4.5776043,
  5.4660335,  2.5080142,  2.6910331,  0.61221725],
 [0.,         1.4883664,  1.0710055,  2.7416446,  4.0853634,  4.193588,
  4.4752164,  3.958254,   3.34505,    0.76900977]])

# %%
# Calculate the mean and standard deviation for each column
fig, ((ax0)) = plt.subplots(nrows=1, ncols=1, sharey=True, figsize=(6, 6))

means1 = np.mean(fp_2N, axis=0)
std_devs1 = np.std(fp_2N, axis=0)

# means11 = np.mean(fg_2N_ic, axis=0)
# std_devs11 = np.std(fg_2N_ic, axis=0)

means2 = np.mean(fp_4N, axis=0)
std_devs2 = np.std(fp_4N, axis=0)

my_xlabels = ['0 nM', '3.125 nM', '6.25 nM', '12.5 nM', '25 nM', '50 nM', '100 nM', '200 nM', '400 nM', '800 nM']
    
# Generate a plot with error bars
x = np.arange(1, 11)  # X-axis points for each column

ax0.set_title(r"$f_p$",fontsize = 20)
ax0.errorbar(x, means1, yerr=std_devs1, fmt='o', capsize=5, color='b', ecolor='b', label='2N')
ax0.errorbar(x, means2, yerr=std_devs2, fmt='o', capsize=5, color='r', ecolor='r', label='4N')
ax0.set_xticks(x, my_xlabels, rotation ='vertical')
ax0.set_xlabel("Drug dose",fontsize = 20)
ax0.legend()


# ax1.set_title(r"$f_g$",fontsize = 20)
# ax1.plot(x,  fg_2N_ic, 'ko', label='2N, using IC50')
# ax1.plot(x,  fg_4N_ic, 'mo', label='4N, using IC50')
# ax1.legend()
# ax1.set_xticks(x, my_xlabels, rotation ='vertical')
# ax1.set_xlabel("Drug dose",fontsize = 20)




plt.show()

# %%
# creating box plots

K1_2N_untx = k1_2N[:,0]
K1_4N_untx = k1_4N[:,0]

# Create a boxplot for each array on the same plot
plt.figure(figsize=(6, 6))
boxprops = dict(linewidth=2)  # Bold box lines
whiskerprops = dict(linewidth=2)  # Bold whisker lines
capprops = dict(linewidth=2)  # Bold cap lines
medianprops = dict(linewidth=2)  # Bold median line

plt.boxplot([K1_2N_untx, K1_4N_untx], labels=['2N', '4N'], widths=0.4,
            boxprops=boxprops, whiskerprops=whiskerprops,
            capprops=capprops, medianprops=medianprops)
# plt.ylabel("Values")
plt.title(r"$k_1$ no_GEM")
plt.show()

# %%
def fg(k1,k1_bar):
    fg = 1-(k1_bar/k1)
    return fg

# %%
c_gem = np.array([0, 3.125, 6.25, 12.5, 25, 50, 100, 200, 400, 800])


def fg_ic50(c_gem,ic50):
    fg = np.zeros(10)
    for i in range(len(c_gem)):
        fg[i] = c_gem[i]/(ic50+c_gem[i])
    return fg

fg_2N_ic=fg_ic50(c_gem,22.93)
fg_4N_ic=fg_ic50(c_gem,73.08)

# %%
print(fg_2N_ic)
# Out:
# [0.         0.11993859 0.2141878  0.35280835 0.52159399 0.68558892
#  0.81347108 0.8971426  0.94578299 0.97213615]

# %%
fg_2N = np.zeros((4,10))
fg_4N = np.zeros((4,10))

for i in range(0,4):
    for j in range(1,10):
        fg_2N[i,j]=fg(k1_2N[i,0],k1_2N[i,j])
        
        
for i in range(0,4):
    for j in range(1,10):
        fg_4N[i,j]=fg(k1_4N[i,0],k1_4N[i,j])

# %%
# Calculate the mean and standard deviation for each column
fig, ((ax0, ax1)) = plt.subplots(nrows=1, ncols=2, sharey=True, figsize=(9, 6))

means1 = np.mean(fg_2N, axis=0)
std_devs1 = np.std(fg_2N, axis=0)

means11 = np.mean(fg_2N_ic, axis=0)
std_devs11 = np.std(fg_2N_ic, axis=0)

means2 = np.mean(fg_4N, axis=0)
std_devs2 = np.std(fg_4N, axis=0)

my_xlabels = ['0 nM', '3.125 nM', '6.25 nM', '12.5 nM', '25 nM', '50 nM', '100 nM', '200 nM', '400 nM', '800 nM']
    
# Generate a plot with error bars
x = np.arange(1, 11)  # X-axis points for each column

ax0.set_title(r"$f_g$",fontsize = 20)
ax0.errorbar(x, means1, yerr=std_devs1, fmt='o', capsize=5, color='b', ecolor='b', label='2N')
ax0.errorbar(x, means2, yerr=std_devs2, fmt='o', capsize=5, color='r', ecolor='r', label='4N')
ax0.set_xticks(x, my_xlabels, rotation ='vertical')
ax0.set_xlabel("Drug dose",fontsize = 20)
ax0.legend()


ax1.set_title(r"$f_g$",fontsize = 20)
ax1.plot(x,  fg_2N_ic, 'ko', label='2N, using IC50')
ax1.plot(x,  fg_4N_ic, 'mo', label='4N, using IC50')
ax1.legend()
ax1.set_xticks(x, my_xlabels, rotation ='vertical')
ax1.set_xlabel("Drug dose",fontsize = 20)




plt.show()

# %%
# k2 2N
k2_2N  = np.array([[1.053243, 0.00081156613, 0.0063987053, 1.359001e-05, 1.3736959e-05, 2.5432384e-05, 1.3774419e-05, 2.4146999e-05, 1.5718468e-05, 3.1869815e-05],
                [1.0055238, 0.7250961, 0.011553881, 1.6299779e-05, 1.1139118e-05, 1.3392701e-05, 1.925655e-05, 2.0995489e-05, 2.6356138e-05, 1.3098797e-06],
                [0.6332954, 0.043113098, 0.0067474335, 1.3461716e-05, 2.0603648e-09, 9.498442e-06, 5.550119e-06, 1.8937495e-05, 2.6356138e-05, 2.1636315e-09],
                [0.937397, 0.4836743, 0.030110296, 4.0825832e-10, 3.941241e-09, 1.23228265e-05, 2.7027361e-05, 1.9485384e-05, 2.6909582e-05, 2.9097544e-05]])

# k2 4N
k2_4N = np.array([[0.8135334, 0.6437733, 0.49626514, 0.028346434, 5.342655e-05, 2.5838568e-05, 3.2197942e-05, 0.000107056636, 1.2324751e-05, 3.29152e-05],
               [0.87190765, 0.89285725, 0.9690127, 0.03978927, 8.558568e-06, 1.1860448e-05, 2.0791871e-05, 4.8762173e-05, 6.646135e-05, 3.2245232e-05],
               [1.0185612, 0.5974986, 0.8094301, 0.026357878, 1.0659491e-05, 1.7472677e-05, 3.6957415e-05, 1.7332564e-05, 0.000105385705, 1.7632806e-09],
               [1.4978892, 0.98398155, 0.6632283, 0.015401162, 1.3817595e-05, 1.4246962e-05, 1.1373764e-05, 4.8806e-05, 1.2430619e-05, 3.350741e-05]])

# %%
# creating box plots

K2_2N_untx = k2_2N[:,0]
K2_4N_untx = k2_4N[:,0]

# Create a boxplot for each array on the same plot
plt.figure(figsize=(6, 6))
boxprops = dict(linewidth=2)  # Bold box lines
whiskerprops = dict(linewidth=2)  # Bold whisker lines
capprops = dict(linewidth=2)  # Bold cap lines
medianprops = dict(linewidth=2)  # Bold median line

plt.boxplot([K2_2N_untx, K2_4N_untx], labels=['2N', '4N'], widths=0.4,
            boxprops=boxprops, whiskerprops=whiskerprops,
            capprops=capprops, medianprops=medianprops)
# plt.ylabel("Values")
plt.title(r"$k_2$ no_GEM")
plt.show()

# %%
def fm(k2,k2_bar):
    fm = 1-(k2_bar/k2)
    return fm

# %%
fm_2N = np.zeros((4,10))
fm_4N = np.zeros((4,10))

for i in range(0,4):
    for j in range(1,10):
        fm_2N[i,j]=fm(k2_2N[i,0],k2_2N[i,j])
        
for i in range(0,4):
    for j in range(1,10):
        fm_4N[i,j]=fm(k2_4N[i,0],k2_4N[i,j])

# %%
# Calculate the mean and standard deviation for each column
fig, ((ax0)) = plt.subplots(nrows=1, ncols=1, sharey=True, figsize=(6, 6))

means1 = np.mean(fm_2N, axis=0)
std_devs1 = np.std(fm_2N, axis=0)

means2 = np.mean(fm_4N, axis=0)
std_devs2 = np.std(fm_4N, axis=0)

my_xlabels = ['0 nM', '3.125 nM', '6.25 nM', '12.5 nM', '25 nM', '50 nM', '100 nM', '200 nM', '400 nM', '800 nM']
    
# Generate a plot with error bars
x = np.arange(1, 11)  # X-axis points for each column

ax0.set_title(r"$f_m$",fontsize = 20)
ax0.errorbar(x, means1, yerr=std_devs1, fmt='o', capsize=5, color='b', ecolor='b', label='2N')
ax0.legend()
ax0.set_xticks(x, my_xlabels, rotation ='vertical')
ax0.set_xlabel("Drug dose",fontsize = 20)

ax0.set_title(r"$f_m$",fontsize = 20)
ax0.errorbar(x, means2, yerr=std_devs2, fmt='o', capsize=5, color='r', ecolor='r', label='4N')
ax0.legend()
ax0.set_xticks(x, my_xlabels, rotation ='vertical')
ax0.set_xlabel("Drug dose",fontsize = 20)




plt.show()

# %%
# k3 2N
k3_2N  = np.array([[1.2652575e-09, 6.2669137e-10, 1.5324242e-10, 8.258925e-06, 2.2117758e-05, 1.1830429e-05, 1.0344998e-05, 1.8684115e-05, 1.8763045e-05, 2.0094369e-05],
                [1.2555217e-09, 2.553762e-06, 2.3662975e-05, 2.7302543e-05, 5.386409e-05, 1.2194472e-05, 4.913936e-05, 1.1786578e-05, 1.5811083e-05, 1.5016724e-06],
                [1.5317593e-06, 1.0701219e-09, 7.540481e-06, 1.941862e-05, 1.6441808e-09, 3.0252457e-05, 8.476682e-06, 2.1800455e-05, 1.5811083e-05, 2.8106724e-09],
                [1.195074e-05, 3.4401219e-06, 2.0819628e-09, 2.845067e-09, 1.493594e-09, 1.3703584e-05, 6.5238455e-05, 5.328256e-05, 4.35915e-05, 2.4886458e-05]])

# k3 4N
k3_4N = np.array([[1.8670398e-05, 0.06992607, 2.7269387e-05, 5.0106348e-05, 7.467288e-05, 5.2767282e-05, 9.202319e-05, 3.108298e-05, 2.3866613e-05, 1.2411554e-05],
               [1.143555e-05, 1.214457e-05, 1.2446385e-05, 9.2909584e-05, 7.722421e-05, 5.5733326e-06, 0.00010190478, 1.9295087e-05, 1.1126249e-05, 3.2444055e-05],
               [2.6240477e-05, 2.800645e-09, 1.2458145e-09, 1.2814227e-05, 5.7610967e-05, 9.861624e-07, 9.162657e-05, 9.4136985e-06, 2.6888134e-05, 3.622419e-11],
               [1.9730594e-05, 1.3433167e-05, 1.2090786e-06, 8.557376e-06, 1.6795608e-05, 1.0731778e-05, 1.3228068e-05, 1.7195434e-05, 1.2115784e-05, 8.187532e-05]])

# %%
def fp(k3,k3_bar):
    fp = 1-(k3_bar/k3)
    return fp

# %%
fp_2N = np.zeros((4,10))
fp_4N = np.zeros((4,10))

for i in range(0,4):
    for j in range(1,10):
        fp_2N[i,j]=fp(k3_2N[i,0],k3_2N[i,j])
        
for i in range(0,4):
    for j in range(1,10):
        fp_4N[i,j]=fp(k3_4N[i,0],k3_4N[i,j])

# %%
import seaborn as sns
import pandas as pd

# Calculate the mean and standard deviation for each column
fig, ((ax0)) = plt.subplots(nrows=1, ncols=1, sharey=True, figsize=(6, 6))

means1 = np.mean(fp_2N, axis=0)
std_devs1 = np.std(fp_2N, axis=0)

means2 = np.mean(fp_4N, axis=0)
std_devs2 = np.std(fp_4N, axis=0)

my_xlabels = ['0 nM', '3.125 nM', '6.25 nM', '12.5 nM', '25 nM', '50 nM', '100 nM', '200 nM', '400 nM', '800 nM']
    
# Generate a plot with error bars
x = np.arange(1, 11)  # X-axis points for each column

ax0.set_title(r"$f_p$",fontsize = 20)
#ax0.errorbar(x, means1, yerr=std_devs1, fmt='o', capsize=5, color='b', ecolor='b', label='2N')
#ax0.legend()
ax0.set_xticks(x[2:], my_xlabels[2:], rotation ='vertical')
ax0.set_xlabel("Drug dose",fontsize = 20)

ax0.set_title(r"$f_p$",fontsize = 20)
ax0.errorbar(x[2:], means2[2:], yerr=std_devs2[2:], fmt='o', capsize=5, color='r', ecolor='r', label='4N')
ax0.legend()
ax0.set_xticks(x[2:], my_xlabels[2:], rotation ='vertical')
ax0.set_xlabel("Drug dose",fontsize = 20)

data = pd.DataFrame({'x': x[2:], 'y': means2[2:]})
df = pd.DataFrame(data)

# Create the scatterplot
ax = sns.regplot(data=df, x='x', y='y')

# Calculate the correlation coefficient
corr_coef = df['x'].corr(df['y'])

# Add the correlation coefficient to the plot
plt.text(0.1, 0.9, f'r = {corr_coef:.2f}', transform=ax.transAxes)


plt.show()

# %%
# kd 2N
kd_2N = np.array([[9.928063e-10, 9.54226e-10, 4.0823034e-09, 0.0140789375, 0.021382483, 0.023388747, 0.021821469, 0.03128245, 0.027007552, 0.028705256],
                [2.1568012e-09, 9.600485e-06, 1.0329372e-05, 0.014891483, 0.024829306, 0.03343253, 0.028666198, 0.029858556, 0.027925353, 0.03168076],
                [1.5061112e-05, 2.6367961e-09, 6.649605e-06, 0.01035227, 0.024580864, 0.02701143, 0.037325915, 0.03035487, 0.027925353, 0.029301152],
                [9.2689035e-05, 2.6479134e-05, 3.4342673e-10, 0.012642843, 0.02754783, 0.02498921, 0.026337272, 0.02555599, 0.02815091, 0.033643402]])

# kd 4N
kd_4N = np.array([[4.3932832e-06, 1.9594705e-05, 1.4696561e-05, 5.7988887e-06, 0.009762482, 0.032732535, 0.031190239, 0.0244276, 0.0237791, 0.021383954],
               [5.2544056e-07, 5.502453e-06, 2.5291833e-06, 1.853504e-05, 0.01235281, 0.025703508, 0.029132232, 0.027532505, 0.024535377, 0.022522919],
               [1.00574e-05, 1.3150458e-09, 3.483545e-09, 1.0141564e-05, 0.009836379, 0.023072276, 0.026158879, 0.028269406, 0.025032971, 0.025338903],
               [1.0631104e-05, 9.643846e-06, 1.1325847e-05, 0.00014550681, 0.012108013, 0.029926486, 0.030407052, 0.026522668, 0.023756707, 0.026039118]])

# %%
# creating box plots

Kd_2N_untx = kd_2N[:,0]
Kd_4N_untx = kd_4N[:,0]

# Create a boxplot for each array on the same plot
plt.figure(figsize=(6, 6))
boxprops = dict(linewidth=2)  # Bold box lines
whiskerprops = dict(linewidth=2)  # Bold whisker lines
capprops = dict(linewidth=2)  # Bold cap lines
medianprops = dict(linewidth=2)  # Bold median line

plt.boxplot([Kd_2N_untx, Kd_4N_untx], labels=['2N', '4N'], widths=0.4,
            boxprops=boxprops, whiskerprops=whiskerprops,
            capprops=capprops, medianprops=medianprops)
# plt.ylabel("Values")
plt.title(r"$k_d$ no_GEM")
plt.show()

# %%
# Calculate the mean and standard deviation for each column
fig, ((ax0)) = plt.subplots(nrows=1, ncols=1, sharey=True, figsize=(14, 5))

means1 = np.mean(kd_2N, axis=0)
std_devs1 = np.std(kd_2N, axis=0)

means2 = np.mean(kd_4N, axis=0)
std_devs2 = np.std(kd_4N, axis=0)

my_xlabels = ['0 nM', '3.125 nM', '6.25 nM', '12.5 nM', '25 nM', '50 nM', '100 nM', '200 nM', '400 nM', '800 nM']
    
# Generate a plot with error bars
x = np.arange(1, 11)  # X-axis points for each column

ax0.set_title(r"$k_d$",fontsize = 20)
ax0.errorbar(x, means1, yerr=std_devs1, fmt='o', capsize=5, color='b', ecolor='b', label='2N')
ax0.legend()
ax0.set_xticks(x, my_xlabels, rotation ='vertical')
ax0.set_xlabel("Drug dose",fontsize = 20)

ax0.set_title(r"$k_d$",fontsize = 20)
ax0.errorbar(x, means2, yerr=std_devs2, fmt='o', capsize=5, color='r', ecolor='r', label='4N')
ax0.legend()
ax0.set_xticks(x, my_xlabels, rotation ='vertical')
ax0.set_xlabel("Drug dose",fontsize = 20)




plt.show()
